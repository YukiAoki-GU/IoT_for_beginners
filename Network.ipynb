# %% [markdown]
# <a href="https://colab.research.google.com/github/YukiAoki-GU/IoT_for_beginners/blob/main/Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ネットワーク入門
# 通信の基本を理解しましょう。
# - HTTP
# - WebSocket
# - MQTT
#
# の3つのプロトコルについてNode-Redを使いながら解説します。

# %% [markdown]
# ## 名前について
# 通信において，「名前」はとても大切な概念です。ネットワークでは
#
# - FQDN (ホスト名+ドメイン名)
# - IPアドレス
# - MACアドレス
#
# の3つの名前がありますので，これらについて理解しましょう。
# 通信時は，DNSを使ってFQDN→IPアドレスの解決，ARPを使ってIPアドレス→MACアドレスの解決を行い，実際の通信はMACアドレスで行います。
#
# FQDNからIPアドレスを知るには
# ```
# host FQDN名
# ```
# です。自身のIPアドレスとMACアドレスを知るには
# ```
# ifconfig
# ```
# です。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('_NScYnLI8Wc', width=400, height=225)

# %% [markdown]
# ## HTTPの基本

# %% [markdown]
# Web通信の基本であるHTTP(HyperText Transfer Protocol)を学びます。
#
#
# HTTPはみなさんがWebサイトを見るとき，当たり前のように使っている通信プロトコルです。
#
# HTTPにはHTTP/1やHTTP/2などがありますが，HTTP/1の基本を学びます。
#
# 一体，どのような通信を行なっているのでしょうか？
#
# HTTPでは下図のように，クライアントからサーバーへのリクエスト，サーバーからクライアントへのレスポンスで通信を行います。

# %% [markdown]
# <img src="https://github.com/YukiAoki-GU/IoT_for_beginners/blob/main/web_pics/client-server.png?raw=1" width="600">

# %% [markdown]
# HTTPリクエストには以下のメソッドがあります。
# - GET
# - POST
# - HEAD
# - OPTIONS
# - PUT
# - DELETE
#
# これらのうちGETがもっとも基本的なメソッドで，ブラウザにURLを入力して検索するとき，GETが使われています。サーバーにGETのリクエストを送ってその応答を見てみましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('GNDFTKGqSPQ', width=400, height=225)

# %% [markdown]
# 次にHTTPのサーバーを自分で立ててみましょう。また，立てたサーバーにリクエストを送り，レスポンスを確認しましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('yt2itrzNbYQ', width=400, height=225)

# %% [markdown]
# HTTPで変数を送る方法を理解しましょう。以下の書式で変数を送ります。
# ```
# FQDN名?変数1=,,,&変数2=,,,
# ```

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Xy5pmhMeXQg', width=400, height=225)

# %% [markdown]
# このようにHTTPプロトコルではヘッダーを用いることで正確な情報通信を行なっています。

# %% [markdown]
# ---
# ## WebSocketの基本

# %% [markdown]
# ヘッダーレスでリアルタイム通信を行うプロトコルがWebSocketです。
#
# WebSocketを使って，IPアドレス:1880/ws1 にタイムスタンプを送り，受け取った結果をデバッグで表示しましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('WrKZvVWudmY', width=400, height=225)

# %% [markdown]
# リアルタイムでタイムスタンプが送られてきますよね。
#
# またデバッグの結果を確認するとヘッダー情報がないことが分かりますよね。

# %% [markdown]
# ---

# %% [markdown]
# ## MQTTについて
#
# 実際のIoTでは多数のセンサ測定を同時に行うため，例えば，各センサーでは10秒おきに測定を行い，センサーが1万個あるような場合があります。
#
# HTTPを使うと，リクエスト・レスポンスのヘッダーが大きくなり，またリアルタイムでの通信もできません。
#
# WebSocketを使うとリアルタイム通信ができますが，1万個のサーバーを立てる必要がありますよね。
#
# こうした問題を解決するために生まれたプロトコルがMQTT(Message Queue Telemetry Transport)です。

# %% [markdown]
# <img src="https://github.com/YukiAoki-GU/IoT_for_beginners/blob/main/web_pics/MQTT1.png?raw=1" width="800">

# %% [markdown]
# MQTTではデータを送るセンサ側はパブリッシャー，データの受信側はサブスクライバーと呼ばれます。
#
# パブリッシャーはヘッダーレスのデータを，データの種類(Topic)を指定して投げるだけです。
#
# サブスクライバーは，指定されたTopicのデータを全て受け取ります。
#
# パブリッシャーとサブスクライバーの間の仲介者が必要となりブローカーと呼ばれます。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('UzpgePEC-Ys', width=400, height=225)

# %% [markdown]
# ---
