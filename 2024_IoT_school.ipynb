# %% [markdown]
# <a href="https://colab.research.google.com/github/YukiAoki-GU/IoT_for_beginners/blob/main/2024_IoT_school.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2024年 IoTスクール受講者テキスト

# %% [markdown]
# #はじめに

# %% [markdown]
# ## スクールの目的
# スクールではラズベリーパイという小型パソコンを使って，スマートホームを作ります。
# - センサー
# - ネットワーク
# - AI
#
# を自在に使いこなすことで，皆さんオリジナルのアイデアを形にしましょう！

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('vq18Z0Hv7Uk', width=400, height=225)

# %% [markdown]
# ---
# ## ラズパイの起動
# 早速，ラズベリーパイを起動してみましょう。
# アダプタを繋ぐと起動開始します。
# 赤のLEDはラズパイに電気が来ていることを確認するものです。
# 緑のLEDが光っている時は，ラズパイが読み込みをしています。
# 緑のLEDが光らなくなったら起動完了です。
#
# 起動が完了したら，ブラウザを立ち上げURL欄に
#
# ホスト名.local:1880
#
# と入力して[Enter]してください。
# Node-REDの画面が表示されたら，ユーザー名とパスワードを入力してください。以上で，起動が完了しました。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('_Hi2hk_3dWA', width=400, height=225)

# %% [markdown]
# ---
# ## Node-REDのイロハ
# Node-REDというアプリケーションを使ってラズパイを制御します。
# Node-REDではコードを書く必要がありません。
# ノードと呼ばれるものを繋げていくだけでプログラミングすることができます。
# ### ノードの繋ぎ方
# ノードの使い方の基礎を勉強しましょう。ノードを繋いだものを「フロー」と呼びますが，フローは左から右に進んでいきます。できたフローを「Deploy」することでプログラムは実行可能になります。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('BG_vQaHn1X0', width=400, height=225)

# %% [markdown]
# ### 入力と出力
# 単純なフローを作って動かしてみましょう。文字列と，数字を出力するフローを作ってみます。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('4P9ZneB09Wc', width=400, height=225)

# %% [markdown]
# ---
# # センサー
# ラズパイに付いているGPIOと呼ばれるピンを使って，センサを制御しましょう。センサとしてはLEDを使います。

# %% [markdown]
# ## LEDのON・OFF
# GPIOから0(オフ)，1(オン)を出力することでLEDを付けたり消したりしましょう。
# ブレッドボードの使い方も勉強します。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('WjDIVtWXA-o', width=400, height=225)

# %% [markdown]
# ## LEDのタイマー制御
# LEDをタイマーで自動でオンオフする方法を勉強しましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('NREEPXf6VwE', width=400, height=225)

# %% [markdown]
# ## ループ
# プログラミングの基本であるループ(繰り返し)の使い方を勉強しましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('t1aL-aQZUiA', width=400, height=225)

# %% [markdown]
# ## 条件分岐
# プログラミングの基本である条件分岐の使い方を勉強しましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('4pUyaos9iLY', width=400, height=225)

# %% [markdown]
# ---
# # ネットワーク
# インターネットを使ったネットワークについて勉強しましょう。

# %% [markdown]
# ## 通信の原理
# 今回使う通信原理のイメージを持ちましょう。
#
# 以下の動画で説明する
#
# 「群馬大学」　→ 「システムクリエイターズ」
#
# と読み替えてください。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('qX_G_2W-ezg', width=400, height=225)

# %% [markdown]
# ## MQTTの原理
# MQTTと呼ばれる通信法(プロトコル)の原理を勉強しましょう。
#
# 以下の動画での説明において
#
# 「群大」　→ 「システムクリエイターズ」
#
# 「stem.idsc-gunma.jp」 → 「ai-server.msep.jp/mqtt」
#
# とそれぞれ読み替えてください。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('BLOyaZ7fsHg', width=400, height=225)

# %% [markdown]
# ## MQTTでLEDの制御
# ネットワーク越しのコンピュータからラズパイにつながっているLEDを制御しましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('yYmsXUWHLsE', width=400, height=225)

# %% [markdown]
# ## スイッチをつけよう
# スマホなどからLEDのオンオフが簡単にできるよう，カッコいい見た目のページを作りましょう。
# このような作業を「UIを作る」と言います。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('SlmAE4yISrI', width=400, height=225)

# %% [markdown]
# ## 写真を送ろう
# ラズパイで撮った写真をネットワーク上のコンピュータに送りましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('mWc_Zcidh9w', width=400, height=225)

# %% [markdown]
# ## 写真をスマホで確認
# 送られてきた写真を表示するためのUIを作りましょう。
# テンプレートノードに書くコードは以下です。
# ```
# <div>
# <img src="data:image/png;base64,{{msg.payload}}">
# </div>
# ```

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('S39pso9gdJo', width=400, height=225)

# %% [markdown]
# ---
# # AI
# 機械学習の基礎を勉強しましょう。

# %% [markdown]
# ## グーチョキパーのAI判定
# [ティーチャブルマシン](https://teachablemachine.withgoogle.com/)というgoogleのアプリを使って，「グー」「チョキ」「パー」をAIで判定しましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('IqrpT_t8dSg', width=400, height=225)

# %% [markdown]
# ## ラズパイでAI
# ティーチャブルマシンで作ったグーチョキパーのAI判定をラズパイの上で使う方法を勉強しましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('h6mkO0XRpvg', width=400, height=225)

# %% [markdown]
# ## しゃべるAI
# スクールの締めくくりです。
# 判定結果を音声でお知らせする方法を勉強しましょう。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('boMG0GhCWpM', width=400, height=225)
